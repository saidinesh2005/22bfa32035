# %% [markdown]
# <a href="https://colab.research.google.com/github/saidinesh2005/22bfa32035/blob/main/Online_retail_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install openpyxl
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting et-xmlfile (from openpyxl)
#   Downloading et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.9/250.9 kB 3.8 MB/s eta 0:00:00
# Downloading et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-2.0.0 openpyxl-3.1.5

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
# !wget https://archive.ics.uci.edu/static/public/352/online+retail.zip
# Out:
# --2025-08-08 01:41:35--  https://archive.ics.uci.edu/static/public/352/online+retail.zip
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified
# Saving to: ‘online+retail.zip’
#
# online+retail.zip       [    <=>             ]  22.62M  29.4MB/s    in 0.8s
#
# 2025-08-08 01:41:36 (29.4 MB/s) - ‘online+retail.zip’ saved [23715478]

# %%
# !unzip online+retail.zip
# Out:
# Archive:  online+retail.zip
#  extracting: Online Retail.xlsx

# %%
df1 = pd.read_excel('Online Retail.xlsx', dtype={'InvoiceNo': 'string', 'StockCode': 'string', 'Description': 'string', 'Country': 'string'})
df1.head(3)
# Out:
#   InvoiceNo StockCode                         Description  Quantity  \
# 0    536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                 WHITE METAL LANTERN         6
# 2    536365    84406B      CREAM CUPID HEARTS COAT HANGER         8
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom

# %%
df1.shape
# Out:
# (541909, 8)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  string
#  1   StockCode    541909 non-null  string
#  2   Description  540455 non-null  string
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  string
# dtypes: datetime64[ns](1), float64(2), int64(1), string(4)
# memory usage: 33.1 MB

# %% [markdown]
# #### Data Cleaning: Handle Missing Values

# %%
df1.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
df1[df1.Description.isnull()]
# Out:
#        InvoiceNo StockCode Description  Quantity         InvoiceDate  \
# 622       536414     22139        <NA>        56 2010-12-01 11:52:00
# 1970      536545     21134        <NA>         1 2010-12-01 14:32:00
# 1971      536546     22145        <NA>         1 2010-12-01 14:33:00
# 1972      536547     37509        <NA>         1 2010-12-01 14:33:00
# 1987      536549    85226A        <NA>         1 2010-12-01 14:34:00
# ...          ...       ...         ...       ...                 ...
# 535322    581199     84581        <NA>        -2 2011-12-07 18:26:00
# 535326    581203     23406        <NA>        15 2011-12-07 18:31:00
# 535332    581209     21620        <NA>         6 2011-12-07 18:35:00
# 536981    581234     72817        <NA>        27 2011-12-08 10:33:00
# 538554    581408     85175        <NA>        20 2011-12-08 14:06:00
#
#         UnitPrice  CustomerID         Country
# 622           0.0         NaN  United Kingdom
# 1970          0.0         NaN  United Kingdom
# 1971          0.0         NaN  United Kingdom
# 1972          0.0         NaN  United Kingdom
# 1987          0.0         NaN  United Kingdom
# ...           ...         ...             ...
# 535322        0.0         NaN  United Kingdom
# 535326        0.0         NaN  United Kingdom
# 535332        0.0         NaN  United Kingdom
# 536981        0.0         NaN  United Kingdom
# 538554        0.0         NaN  United Kingdom
#
# [1454 rows x 8 columns]

# %%
df1[df1.StockCode=="22139"].Description.mode()
# Out:
# 0    RETROSPOT TEA SET CERAMIC 11 PC
# Name: Description, dtype: string

# %%
most_freq = df1[["StockCode","Description"]].value_counts().reset_index()
most_freq
# Out:
#      StockCode                         Description  count
# 0       85123A  WHITE HANGING HEART T-LIGHT HOLDER   2302
# 1        22423            REGENCY CAKESTAND 3 TIER   2200
# 2       85099B             JUMBO BAG RED RETROSPOT   2159
# 3        47566                       PARTY BUNTING   1727
# 4        20725             LUNCH BAG RED RETROSPOT   1638
# ...        ...                                 ...    ...
# 4787    35833P                               check      1
# 4788     21410     COUNTRY COTTAGE  DOORSTOP GREEN      1
# 4789     21412            VINTAGE GOLD TINSEL REEL      1
# 4790     21414             SCALLOP SHELL SOAP DISH      1
# 4791     35972                               check      1
#
# [4792 rows x 3 columns]

# %%
most_freq[most_freq.StockCode=="85123A"].head(1)
# Out:
#   StockCode                         Description  count
# 0    85123A  WHITE HANGING HEART T-LIGHT HOLDER   2302

# %%
most_freq.columns = ["StockCode", "freq_Description", "count"]
df2 = df1.merge(most_freq, on="StockCode", how="left")
df2.head()
# Out:
#   InvoiceNo StockCode                         Description  Quantity  \
# 0    536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 2    536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 3    536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 4    536365     71053                 WHITE METAL LANTERN         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  \
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
#
#                      freq_Description   count
# 0  WHITE HANGING HEART T-LIGHT HOLDER  2302.0
# 1  CREAM HANGING HEART T-LIGHT HOLDER     9.0
# 2         wrongly marked carton 22804     1.0
# 3                                   ?     1.0
# 4                 WHITE METAL LANTERN   328.0

# %%
df2['Description'] = df2["freq_Description"]
df2.head()
# Out:
#   InvoiceNo StockCode                         Description  Quantity  \
# 0    536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365    85123A  CREAM HANGING HEART T-LIGHT HOLDER         6
# 2    536365    85123A         wrongly marked carton 22804         6
# 3    536365    85123A                                   ?         6
# 4    536365     71053                 WHITE METAL LANTERN         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  \
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
#
#                      freq_Description   count
# 0  WHITE HANGING HEART T-LIGHT HOLDER  2302.0
# 1  CREAM HANGING HEART T-LIGHT HOLDER     9.0
# 2         wrongly marked carton 22804     1.0
# 3                                   ?     1.0
# 4                 WHITE METAL LANTERN   328.0

# %%
df2.isnull().sum()
# Out:
# InvoiceNo                0
# StockCode                0
# Description            112
# Quantity                 0
# InvoiceDate              0
# UnitPrice                0
# CustomerID          171188
# Country                  0
# freq_Description       112
# count                  112
# dtype: int64

# %%
df2.dropna(subset=["Description"], inplace=True)
df2.isnull().sum()
# Out:
# InvoiceNo                0
# StockCode                0
# Description              0
# Quantity                 0
# InvoiceDate              0
# UnitPrice                0
# CustomerID          171076
# Country                  0
# freq_Description         0
# count                    0
# dtype: int64

# %%
df2.drop(columns = ["freq_Description", "count"], inplace=True)
df2.head()
# Out:
#   InvoiceNo StockCode                         Description  Quantity  \
# 0    536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365    85123A  CREAM HANGING HEART T-LIGHT HOLDER         6
# 2    536365    85123A         wrongly marked carton 22804         6
# 3    536365    85123A                                   ?         6
# 4    536365     71053                 WHITE METAL LANTERN         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
df2.describe()
# Out:
#             Quantity                    InvoiceDate      UnitPrice  \
# count  710919.000000                         710919  710919.000000
# mean        9.718405  2011-07-05 11:53:55.375253248       4.410160
# min    -80995.000000            2010-12-01 08:26:00  -11062.060000
# 25%         1.000000            2011-03-29 15:12:00       1.250000
# 50%         3.000000            2011-07-20 16:17:00       2.100000
# 75%        10.000000            2011-10-19 10:31:00       4.130000
# max     80995.000000            2011-12-09 12:50:00   38970.000000
# std       194.114446                            NaN      84.525607
#
#           CustomerID
# count  539843.000000
# mean    15290.162562
# min     12346.000000
# 25%     13956.000000
# 50%     15152.000000
# 75%     16791.000000
# max     18287.000000
# std      1709.392583

# %%
df2[df2.UnitPrice<0]
# Out:
#        InvoiceNo StockCode      Description  Quantity         InvoiceDate  \
# 391449   A563186         B  Adjust bad debt         1 2011-08-12 14:51:00
# 391450   A563187         B  Adjust bad debt         1 2011-08-12 14:52:00
#
#         UnitPrice  CustomerID         Country
# 391449  -11062.06         NaN  United Kingdom
# 391450  -11062.06         NaN  United Kingdom

# %%
df3 = df2[(df2.UnitPrice>0) & (df2.Quantity>0)]
df3.describe()
# Out:
#             Quantity                    InvoiceDate      UnitPrice  \
# count  693945.000000                         693945  693945.000000
# mean       10.873889  2011-07-05 15:59:13.143203328       3.874301
# min         1.000000            2010-12-01 08:26:00       0.001000
# 25%         1.000000            2011-03-29 15:20:00       1.250000
# 50%         4.000000            2011-07-21 10:44:00       2.100000
# 75%        12.000000            2011-10-19 11:49:00       4.130000
# max     80995.000000            2011-12-09 12:50:00   13541.330000
# std       137.669424                            NaN      31.507544
#
#           CustomerID
# count  527365.000000
# mean    15296.797165
# min     12346.000000
# 25%     13969.000000
# 50%     15159.000000
# 75%     16794.000000
# max     18287.000000
# std      1708.785281

# %%
df3.Quantity.quantile(0.9999)
# Out:
# np.float64(1530.1399999973364)

# %%
df3[df3.Quantity>1500].head(3)
# Out:
#       InvoiceNo StockCode                        Description  Quantity  \
# 6336     536809     84950     ASSORTED COLOUR T-LIGHT HOLDER      1824
# 6472     536830     84077  WORLD WAR 2 GLIDERS ASSTD DESIGNS      2880
# 33829    538420     17096  ASSORTED LAQUERED INCENSE HOLDERS      1728
#
#               InvoiceDate  UnitPrice  CustomerID         Country
# 6336  2010-12-02 16:48:00       0.55     15299.0  United Kingdom
# 6472  2010-12-02 17:38:00       0.18     16754.0  United Kingdom
# 33829 2010-12-12 12:03:00       0.17     12875.0  United Kingdom

# %% [markdown]
# ####Feature Engineering:Create New Columns

# %%
df4 = df3.copy()
df4['TotalSales'] = df4['Quantity'] * df4['UnitPrice']
df4.head(3)
# Out:
#   InvoiceNo StockCode                         Description  Quantity  \
# 0    536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365    85123A  CREAM HANGING HEART T-LIGHT HOLDER         6
# 2    536365    85123A         wrongly marked carton 22804         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  TotalSales
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom        15.3
# 1 2010-12-01 08:26:00       2.55     17850.0  United Kingdom        15.3
# 2 2010-12-01 08:26:00       2.55     17850.0  United Kingdom        15.3

# %%
df4['Month'] = df4['InvoiceDate'].dt.month
df4.sample(5)
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 642242    577809     23243  SET OF TEA COFFEE SUGAR TINS PANTRY         4
# 689472    580610     21803                                check         5
# 193449    549417     84880                WHITE WIRE EGG HOLDER        12
# 361978    561147     21159              MOODY BOY  DOOR HANGER         24
# 571341    574055     22169     FAMILY ALBUM WHITE PICTURE FRAME         8
#
#                InvoiceDate  UnitPrice  CustomerID         Country  TotalSales  \
# 642242 2011-11-22 08:34:00       4.95     12584.0           Italy       19.80
# 689472 2011-12-05 11:48:00       0.83         NaN  United Kingdom        4.15
# 193449 2011-04-08 11:44:00       6.65     14258.0  United Kingdom       79.80
# 361978 2011-07-25 13:06:00       0.39     16841.0  United Kingdom        9.36
# 571341 2011-11-02 14:08:00       7.65     16525.0  United Kingdom       61.20
#
#         Month
# 642242     11
# 689472     12
# 193449      4
# 361978      7
# 571341     11

# %% [markdown]
# ####Visualization & EDA

# %% [markdown]
# #####1. Plot Monthly Sales

# %%
monthly_sales = df4.groupby('Month')['TotalSales'].sum()
monthly_sales.plot(kind='line',title="Monthly Sales", marker="o")
plt.xlabel('Month')
plt.ylabel('Total Sales')
plt.grid()
plt.show()

# %% [markdown]
# **Insights**
#
# Total sales started rising up in August having a peek in November. This is likely due to the holiday season at the end of the year

# %% [markdown]
# #####2.Top 5 Countries

# %%
top_5_countries = df4.groupby('Country')['TotalSales'].sum().sort_values(ascending=False).head(5)
top_5_countries
# Out:
# Country
# United Kingdom    1.269449e+07
# Netherlands       4.316229e+05
# EIRE              3.937788e+05
# Germany           3.051400e+05
# France            3.028098e+05
# Name: TotalSales, dtype: float64

# %%
top_5_countries.plot(kind='bar', title='Top 5 Countries by Total Sales')
plt.xlabel('Total Sales')
plt.ylabel('Country')
plt.grid(axis='x')
plt.show()

# %%
import pandas as pd
from matplotlib import pyplot as plt
import matplotlib.pyplot as plt

country_wise_sales = df4.groupby('Country')['TotalSales'].sum()
total_sales = country_wise_sales.sum()
top_5_countries = country_wise_sales.sort_values(ascending=False).head(5)
percentage = (top_5_countries / total_sales) * 100

plt.figure(figsize=(10, 6))
bars = plt.bar(top_5_countries.index, percentage)
plt.xlabel('Percentage Contribution to Total Sales')
plt.ylabel('Country')
plt.title('Top 5 Countries by Percentage Contribution to Total Sales')
plt.grid(axis='x')

for bar, percentage in zip(bars, percentage):
    plt.text(bar.get_width() + bar.get_y() / 2, bar.get_height()/2, f'{percentage:.1f}%', ha='center')

plt.show()

# %%
product_wise_sales = df4.groupby('StockCode')['TotalSales'].sum()

top_5_products = product_wise_sales.sort_values(ascending=False).head(5)
top_5_products.plot(kind='bar', color='skyblue')
plt.title('Product-wise Sales')
plt.xlabel('Total Sales')
plt.ylabel('Product StockCode')
plt.gca().invert_yaxis()
plt.show()

# %%
product_wise_sales.sort_values(ascending=False)
# Out:
# StockCode
# 22423     523454.220
# 23084     468754.930
# 85123A    418075.200
# DOT       206248.770
# 20713     184247.680
#              ...
# 90084          0.850
# 21268          0.840
# 51014c         0.830
# 84227          0.420
# PADS           0.003
# Name: TotalSales, Length: 3922, dtype: float64

# %%
product_wise_sales.sum()
# Out:
# np.float64(15027573.934)

# %%
df4[df4.StockCode=="DOT"]
# Out:
#        InvoiceNo StockCode     Description  Quantity         InvoiceDate  \
# 2364      536544       DOT  DOTCOM POSTAGE         1 2010-12-01 14:32:00
# 3927      536592       DOT  DOTCOM POSTAGE         1 2010-12-01 17:06:00
# 7143      536862       DOT  DOTCOM POSTAGE         1 2010-12-03 11:13:00
# 7268      536864       DOT  DOTCOM POSTAGE         1 2010-12-03 11:27:00
# 7450      536865       DOT  DOTCOM POSTAGE         1 2010-12-03 11:28:00
# ...          ...       ...             ...       ...                 ...
# 704672    581219       DOT  DOTCOM POSTAGE         1 2011-12-08 09:28:00
# 705202    581238       DOT  DOTCOM POSTAGE         1 2011-12-08 10:53:00
# 707914    581439       DOT  DOTCOM POSTAGE         1 2011-12-08 16:30:00
# 709774    581492       DOT  DOTCOM POSTAGE         1 2011-12-09 10:03:00
# 710558    581498       DOT  DOTCOM POSTAGE         1 2011-12-09 10:26:00
#
#         UnitPrice  CustomerID         Country  TotalSales  Month
# 2364       569.77         NaN  United Kingdom      569.77     12
# 3927       607.49         NaN  United Kingdom      607.49     12
# 7143       254.43         NaN  United Kingdom      254.43     12
# 7268       121.06         NaN  United Kingdom      121.06     12
# 7450       498.47         NaN  United Kingdom      498.47     12
# ...           ...         ...             ...         ...    ...
# 704672    1008.96         NaN  United Kingdom     1008.96     12
# 705202    1683.75         NaN  United Kingdom     1683.75     12
# 707914     938.59         NaN  United Kingdom      938.59     12
# 709774     933.17         NaN  United Kingdom      933.17     12
# 710558    1714.17         NaN  United Kingdom     1714.17     12
#
# [706 rows x 10 columns]

# %%
for stock_code in top_5_products.index:
    description = df4[df4.StockCode==stock_code].Description.iloc[0]
    print(f"{stock_code} ==> {description}")
# Out:
# 22423 ==> REGENCY CAKESTAND 3 TIER
# 23084 ==> RABBIT NIGHT LIGHT
# 85123A ==> WHITE HANGING HEART T-LIGHT HOLDER
# DOT ==> DOTCOM POSTAGE
# 20713 ==> JUMBO BAG OWLS

# %%
total_sales = product_wise_sales.sum()
percentages = (top_5_products / total_sales) * 100

plt.figure(figsize=(10, 6))
bars = plt.bar(top_5_products.index, percentages)
plt.xlabel('Percentage Contribution to Total Sales')
plt.ylabel('Product StockCode')
plt.title('Top 5 Products by Percentage Contribution to Total Sales')
plt.grid(axis='x')

for bar, percentage in zip(bars, percentages):
    plt.text(bar.get_width() + 0.5, bar.get_y() + bar.get_height()/2, f'{percentage:.1f}%', va='center')

plt.show()

# %% [markdown]
# ####4.RFM Analysis

# %%
current_dt = df4["InvoiceDate"].max() + pd.Timedelta(days=1)
current_dt
# Out:
# Timestamp('2011-12-10 12:50:00')

# %%
rfm = df4.groupby("CustomerID").agg({
    "InvoiceDate": lambda x: (current_dt - x.max()).days,
    "InvoiceNo": "count",
    "TotalSales": "sum"
})

rfm.columns = ["Recency", "Frequency", "Monetary"]
rfm.head(5)
# Out:
#             Recency  Frequency  Monetary
# CustomerID
# 12346.0         326          1  77183.60
# 12347.0           2        227   5971.21
# 12348.0          75         34   1930.44
# 12349.0          19         92   2165.86
# 12350.0         310         19    364.40

# %%
df4[df4.CustomerID==12347]["TotalSales"].sum()
# Out:
# np.float64(5971.210000000001)

# %%
rfm['R_Segment'] = pd.qcut(rfm['Recency'], 4, labels=[4, 3, 2, 1])
rfm['F_Segment'] = pd.qcut(rfm['Frequency'], 4, labels=[1, 2, 3, 4])
rfm['M_Segment'] = pd.qcut(rfm['Monetary'], 4, labels=[1, 2, 3, 4])
rfm['RFM_Score'] = rfm[['R_Segment', 'F_Segment', 'M_Segment']].sum(axis=1)
rfm
# Out:
#             Recency  Frequency  Monetary R_Segment F_Segment M_Segment  \
# CustomerID
# 12346.0         326          1  77183.60         1         1         4
# 12347.0           2        227   5971.21         4         4         4
# 12348.0          75         34   1930.44         2         2         3
# 12349.0          19         92   2165.86         3         3         3
# 12350.0         310         19    364.40         1         1         1
# ...             ...        ...       ...       ...       ...       ...
# 18280.0         278         12    211.20         1         1         1
# 18281.0         181         12    160.92         1         1         1
# 18282.0           8         17    269.97         4         1         1
# 18283.0           4        987   3058.74         4         4         4
# 18287.0          43         83   2033.24         3         3         3
#
#             RFM_Score
# CustomerID
# 12346.0             6
# 12347.0            12
# 12348.0             7
# 12349.0             9
# 12350.0             3
# ...               ...
# 18280.0             3
# 18281.0             3
# 18282.0             6
# 18283.0            12
# 18287.0             9
#
# [4338 rows x 7 columns]

# %%
rfm.sort_values('RFM_Score', ascending=False)
# Out:
#             Recency  Frequency  Monetary R_Segment F_Segment M_Segment  \
# CustomerID
# 12362.0           3        330   6374.86         4         4         4
# 15194.0           3        406  10150.04         4         4         4
# 15271.0           7        344   3385.22         4         4         4
# 15218.0          11        253   8991.13         4         4         4
# 15298.0           2        256   7658.92         4         4         4
# ...             ...        ...       ...       ...       ...       ...
# 12350.0         310         19    364.40         1         1         1
# 12977.0         156          9     39.24         1         1         1
# 17639.0         276          8    128.40         1         1         1
# 17643.0         373         11    138.30         1         1         1
# 12888.0         214          5    354.12         1         1         1
#
#             RFM_Score
# CustomerID
# 12362.0            12
# 15194.0            12
# 15271.0            12
# 15218.0            12
# 15298.0            12
# ...               ...
# 12350.0             3
# 12977.0             3
# 17639.0             3
# 17643.0             3
# 12888.0             3
#
# [4338 rows x 7 columns]

# %% [markdown]
# 5.Customer Churn Analysis

# %%
df4.head(2)
# Out:
#   InvoiceNo StockCode                         Description  Quantity  \
# 0    536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365    85123A  CREAM HANGING HEART T-LIGHT HOLDER         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  TotalSales  \
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom        15.3
# 1 2010-12-01 08:26:00       2.55     17850.0  United Kingdom        15.3
#
#    Month
# 0     12
# 1     12

# %%
customer_last_purchase = df4.groupby("CustomerID")['InvoiceDate'].max()
customer_last_purchase.head(5)
# Out:
# CustomerID
# 12346.0   2011-01-18 10:01:00
# 12347.0   2011-12-07 15:52:00
# 12348.0   2011-09-25 13:13:00
# 12349.0   2011-11-21 09:51:00
# 12350.0   2011-02-02 16:01:00
# Name: InvoiceDate, dtype: datetime64[ns]

# %%
type(customer_last_purchase)
# Out:
# pandas.core.series.Series

# %%
current_dt
# Out:
# Timestamp('2011-12-10 12:50:00')

# %%
customer_last_purchase = (current_dt - customer_last_purchase).dt.days
customer_last_purchase.head(5)
# Out:
# CustomerID
# 12346.0    326
# 12347.0      2
# 12348.0     75
# 12349.0     19
# 12350.0    310
# Name: InvoiceDate, dtype: int64

# %%
churn_threshold = 90
churned_customers = customer_last_purchase[customer_last_purchase > churn_threshold]
churned_customers.head(5)
# Out:
# CustomerID
# 12346.0    326
# 12350.0    310
# 12353.0    204
# 12354.0    232
# 12355.0    214
# Name: InvoiceDate, dtype: int64

# %%
print("Number of churned Customers:", len(churned_customers))
plt.figure(figsize=(10, 6))
plt.hist(customer_last_purchase, bins=50, color='red', alpha=0.7)
plt.axvline(churn_threshold, color='black', linestyle='dashed', linewidth=2)
plt.title('Customer Churn Distribution')
plt.xlabel('Days Since Last Purchase')
plt.ylabel('Number of Customers')
plt.show()
# Out:
# Number of churned Customers: 1449
